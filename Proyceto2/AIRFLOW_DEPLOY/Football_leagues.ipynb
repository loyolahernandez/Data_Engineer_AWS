# %%
import pandas as pd 
import time
import random
import os
from utils import get_data,data_processing
from datetime import datetime
import uuid

# %%
url = ['https://www.espn.com.co/futbol/posiciones/_/liga/esp.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ita.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ger.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/fra.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/por.1',
      'https://www.espn.com.co/futbol/posiciones/_/liga/ned.1']
ligas = ['ESPAÑA','INGLATERRA','ITALIA','GERMANY','FRANCIA','PORTUGAL','HOLANDA']

df_ligas = {
    'LIGA':ligas,
    'URL':url
} 

df_ligas = pd.DataFrame(df_ligas)
df_ligas
# Out:
#          LIGA                                                URL
# 0      ESPAÑA  https://www.espn.com.co/futbol/posiciones/_/li...
# 1  INGLATERRA  https://www.espn.com.co/futbol/posiciones/_/li...
# 2      ITALIA  https://www.espn.com.co/futbol/posiciones/_/li...
# 3     GERMANY  https://www.espn.com.co/futbol/posiciones/_/li...
# 4     FRANCIA  https://www.espn.com.co/futbol/posiciones/_/li...
# 5    PORTUGAL  https://www.espn.com.co/futbol/posiciones/_/li...
# 6     HOLANDA  https://www.espn.com.co/futbol/posiciones/_/li...

# %%
df_ligas['URL'][1]
# Out:
# 'https://www.espn.com.co/futbol/posiciones/_/liga/eng.1'

# %%
df = pd.read_html(df_ligas['URL'][1])

# %%
len(df)
# Out:
# 2

# %%
df[0]
# Out:
#                        2024/2025
# 0     1BHABrighton & Hove Albion
# 1                    2ARSArsenal
# 2                  3LIVLiverpool
# 3            4MCIManchester City
# 4                5AVLAston Villa
# 5                  6BRNBrentford
# 6          7MUNManchester United
# 7           8NEWNewcastle United
# 8            9BOUAFC Bournemouth
# 9            10LEILeicester City
# 10        11FORNottingham Forest
# 11        12TOTTottenham Hotspur
# 12           13CRYCrystal Palace
# 13          14WHUWest Ham United
# 14                   15FULFulham
# 15              16SOUSouthampton
# 16                  17CHEChelsea
# 17             18IPSIpswich Town
# 18  19WOLWolverhampton Wanderers
# 19                  20EVEEverton

# %%
df[1]
# Out:
#     J  G  E  P  GF  GC  DIF  PTS
# 0   1  1  0  0   3   0    3    3
# 1   1  1  0  0   2   0    2    3
# 2   1  1  0  0   2   0    2    3
# 3   1  1  0  0   2   0    2    3
# 4   1  1  0  0   2   1    1    3
# 5   1  1  0  0   2   1    1    3
# 6   1  1  0  0   1   0    1    3
# 7   1  1  0  0   1   0    1    3
# 8   1  0  1  0   1   1    0    1
# 9   1  0  1  0   1   1    0    1
# 10  1  0  1  0   1   1    0    1
# 11  1  0  1  0   1   1    0    1
# 12  1  0  0  1   1   2   -1    0
# 13  1  0  0  1   1   2   -1    0
# 14  1  0  0  1   0   1   -1    0
# 15  1  0  0  1   0   1   -1    0
# 16  1  0  0  1   0   2   -2    0
# 17  1  0  0  1   0   2   -2    0
# 18  1  0  0  1   0   2   -2    0
# 19  1  0  0  1   0   3   -3    0

# %%
df=pd.concat([df[0],df[1]],ignore_index=True,axis=1)
df
# Out:
#                                0  1  2  3  4  5  6  7  8
# 0     1BHABrighton & Hove Albion  1  1  0  0  3  0  3  3
# 1                    2ARSArsenal  1  1  0  0  2  0  2  3
# 2                  3LIVLiverpool  1  1  0  0  2  0  2  3
# 3            4MCIManchester City  1  1  0  0  2  0  2  3
# 4                5AVLAston Villa  1  1  0  0  2  1  1  3
# 5                  6BRNBrentford  1  1  0  0  2  1  1  3
# 6          7MUNManchester United  1  1  0  0  1  0  1  3
# 7           8NEWNewcastle United  1  1  0  0  1  0  1  3
# 8            9BOUAFC Bournemouth  1  0  1  0  1  1  0  1
# 9            10LEILeicester City  1  0  1  0  1  1  0  1
# 10        11FORNottingham Forest  1  0  1  0  1  1  0  1
# 11        12TOTTottenham Hotspur  1  0  1  0  1  1  0  1
# 12           13CRYCrystal Palace  1  0  0  1  1  2 -1  0
# 13          14WHUWest Ham United  1  0  0  1  1  2 -1  0
# 14                   15FULFulham  1  0  0  1  0  1 -1  0
# 15              16SOUSouthampton  1  0  0  1  0  1 -1  0
# 16                  17CHEChelsea  1  0  0  1  0  2 -2  0
# 17             18IPSIpswich Town  1  0  0  1  0  2 -2  0
# 18  19WOLWolverhampton Wanderers  1  0  0  1  0  2 -2  0
# 19                  20EVEEverton  1  0  0  1  0  3 -3  0

# %%
df=df.rename(columns={0:'EQUIPO',1:'J', 2:'G', 3:'E', 4:'P', 5:'GF', 6:'GC', 7:'DIF', 8:'PTS'})
df['EQUIPO']=df['EQUIPO'].apply(lambda x: x[5:] if x[:2].isnumeric()==True else x[4:])
df['LIGA'] = df_ligas['LIGA'][1]

# %%
df
# Out:
#                      EQUIPO  J  G  E  P  GF  GC  DIF  PTS        LIGA
# 0    Brighton & Hove Albion  1  1  0  0   3   0    3    3  INGLATERRA
# 1                   Arsenal  1  1  0  0   2   0    2    3  INGLATERRA
# 2                 Liverpool  1  1  0  0   2   0    2    3  INGLATERRA
# 3           Manchester City  1  1  0  0   2   0    2    3  INGLATERRA
# 4               Aston Villa  1  1  0  0   2   1    1    3  INGLATERRA
# 5                 Brentford  1  1  0  0   2   1    1    3  INGLATERRA
# 6         Manchester United  1  1  0  0   1   0    1    3  INGLATERRA
# 7          Newcastle United  1  1  0  0   1   0    1    3  INGLATERRA
# 8           AFC Bournemouth  1  0  1  0   1   1    0    1  INGLATERRA
# 9            Leicester City  1  0  1  0   1   1    0    1  INGLATERRA
# 10        Nottingham Forest  1  0  1  0   1   1    0    1  INGLATERRA
# 11        Tottenham Hotspur  1  0  1  0   1   1    0    1  INGLATERRA
# 12           Crystal Palace  1  0  0  1   1   2   -1    0  INGLATERRA
# 13          West Ham United  1  0  0  1   1   2   -1    0  INGLATERRA
# 14                   Fulham  1  0  0  1   0   1   -1    0  INGLATERRA
# 15              Southampton  1  0  0  1   0   1   -1    0  INGLATERRA
# 16                  Chelsea  1  0  0  1   0   2   -2    0  INGLATERRA
# 17             Ipswich Town  1  0  0  1   0   2   -2    0  INGLATERRA
# 18  Wolverhampton Wanderers  1  0  0  1   0   2   -2    0  INGLATERRA
# 19                  Everton  1  0  0  1   0   3   -3    0  INGLATERRA

# %%
df_ligas.to_csv('df_ligas.csv',index=False)

# %%
def id_generator(team):

    return str(uuid.uuid1())[:8]

# %%
id_generator('carro')

# %%
id_generator('gato')

# %%
lista_resultado = 0

# %%
equipos = df_hola['EQUIPO'].unique()
lista_resultado = list(map(id_generator, equipos))

# %%
team_table = {

    'EQUIPO':equipos,
    'ID_TEAM':lista_resultado
}

df_team = pd.DataFrame(team_table)

# %%
df_team['ID_TEAM'].value_counts()

# %%
df_team.to_csv('team_table.csv',index=False)

# %%
pd.read_csv('df_ligas.csv')

# %%
df_final = pd.merge(df_hola,df_team,how='inner',on='EQUIPO')
df_final.columns
df_final = df_final[['ID_TEAM','EQUIPO', 'J', 'G', 'E', 'P', 'GF', 'GC', 'DIF', 'PTS', 'LIGA',
       'CREATED_AT']]
df_final

# %%
df_final.to_csv('premier_positions.csv',index=False)

# %%
lista_resultado[0]

# %%
hash('hola')

# %%
df_hola
